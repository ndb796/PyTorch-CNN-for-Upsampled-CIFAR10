# %% [markdown]
# #### <b>ResNet18 모델 아키텍처 정의</b>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out) # 출력: [batch_size, 512, 4, 4]
        out = F.avg_pool2d(out, 8) # 출력: [batch_size, 512, 1, 1]
        out = out.view(out.size(0), -1) # 출력: [batch_size, 512]
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# #### <b>데이터셋(Dataset) 다운로드 및 불러오기</b>

# %%
import torchvision
import torchvision.transforms as transforms

transform_train = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# #### <b>환경 설정 및 학습(Training) 함수 정의</b>

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)

learning_rate = 0.1
file_name = 'resnet18_cifar10.pth'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        current_correct = predicted.eq(targets).sum().item()
        correct += current_correct
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current batch average train accuracy:', current_correct / targets.size(0))
            print('Current batch average train loss:', loss.item() / targets.size(0))

    print('\nTotal average train accuarcy:', correct / total)
    print('Total average train loss:', train_loss / total)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTotal average test accuarcy:', correct / total)
    print('Total average test loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

# %% [markdown]
# #### <b>학습(Training) 진행</b>

# %%
import time


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 30:
        lr /= 10
    if epoch >= 40:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

start_time = time.time()

for epoch in range(0, 50):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
    print('\nTime elapsed:', time.time() - start_time)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.109375
# Current batch average train loss: 0.040035173296928406
#
# Current batch: 100
# Current batch average train accuracy: 0.234375
# Current batch average train loss: 0.031232818961143494
#
# Current batch: 200
# Current batch average train accuracy: 0.296875
# Current batch average train loss: 0.02819729410111904
#
# Current batch: 300
# Current batch average train accuracy: 0.25
# Current batch average train loss: 0.029423678293824196
#
# Current batch: 400
# Current batch average train accuracy: 0.359375
# Current batch average train loss: 0.025452444329857826
#
# Current batch: 500
# Current batch average train accuracy: 0.3125
# Current batch average train loss: 0.02563570998609066
#
# Current batch: 600
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.02542552351951599
#
# Current batch: 700
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.02307257615029812
#
# Total average train accuarcy: 0.3301
# Total average train loss: 0.02885616456270218
#
# [ Test epoch: 0 ]
#
# Total average test accuarcy: 0.3843
# Total average test loss: 0.027590973508358003
# Model Saved!
#
# Time elapsed: 317.31176710128784
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.34375
# Current batch average train loss: 0.02840135619044304
#
# Current batch: 100
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.023631228134036064
#
# Current batch: 200
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.022914255037903786
#
# Current batch: 300
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.02084314078092575
#
# Current batch: 400
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.018878478556871414
#
# Current batch: 500
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.020931605249643326
#
# Current batch: 600
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.01656334660947323
#
# Current batch: 700
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.01707763597369194
#
# Total average train accuarcy: 0.52168
# Total average train loss: 0.020511963423490525
#
# [ Test epoch: 1 ]
#
# Total average test accuarcy: 0.5862
# Total average test loss: 0.01838761289715767
# Model Saved!
#
# Time elapsed: 634.7466423511505
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.014812357723712921
#
# Current batch: 100
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.015258220955729485
#
# Current batch: 200
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.013113366439938545
#
# Current batch: 300
# Current batch average train accuracy: 0.765625
# Current batch average train loss: 0.01327110081911087
#
# Current batch: 400
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.010567967779934406
#
# Current batch: 500
# Current batch average train accuracy: 0.703125
# Current batch average train loss: 0.013440863229334354
#
# Current batch: 600
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.010768852196633816
#
# Current batch: 700
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.017056569457054138
#
# Total average train accuarcy: 0.6723
# Total average train loss: 0.014449126477241517
#
# [ Test epoch: 2 ]
#
# Total average test accuarcy: 0.66
# Total average test loss: 0.015603446370363235
# Model Saved!
#
# Time elapsed: 954.5031769275665
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.00794281717389822
#
# Current batch: 100
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.011078313924372196
#
# Current batch: 200
# Current batch average train accuracy: 0.734375
# Current batch average train loss: 0.011582820676267147
#
# Current batch: 300
# Current batch average train accuracy: 0.765625
# Current batch average train loss: 0.010248694568872452
#
# Current batch: 400
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.01039624772965908
#
# Current batch: 500
# Current batch average train accuracy: 0.703125
# Current batch average train loss: 0.01033842097967863
#
# Current batch: 600
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.008642627857625484
#
# Current batch: 700
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.011283830739557743
#
# Total average train accuarcy: 0.76056
# Total average train loss: 0.010774323199391365
#
# [ Test epoch: 3 ]
#
# Total average test accuarcy: 0.7301
# Total average test loss: 0.012497548669576645
# Model Saved!
#
# Time elapsed: 1272.7847619056702
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.765625
# Current batch average train loss: 0.009157535620033741
#
# Current batch: 100
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.009204668924212456
#
# Current batch: 200
# Current batch average train accuracy: 0.765625
# Current batch average train loss: 0.01027541421353817
#
# Current batch: 300
# Current batch average train accuracy: 0.734375
# Current batch average train loss: 0.010975425131618977
#
# Current batch: 400
# Current batch average train accuracy: 0.734375
# Current batch average train loss: 0.010227960534393787
#
# Current batch: 500
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.006006136070936918
#
# Current batch: 600
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.007353753782808781
#
# Current batch: 700
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.0076419152319431305
#
# Total average train accuarcy: 0.80026
# Total average train loss: 0.008965420449376106
#
# [ Test epoch: 4 ]
#
# Total average test accuarcy: 0.7908
# Total average test loss: 0.00931521276831627
# Model Saved!
#
# Time elapsed: 1592.0262413024902
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.008413158357143402
#
# Current batch: 100
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.008848457597196102
#
# Current batch: 200
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.008906399831175804
#
# Current batch: 300
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.010569389909505844
#
# Current batch: 400
# Current batch average train accuracy: 0.796875
# Current batch average train loss: 0.007220002822577953
#
# Current batch: 500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.008371533825993538
#
# Current batch: 600
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.008283074013888836
#
# Current batch: 700
# Current batch average train accuracy: 0.765625
# Current batch average train loss: 0.008954760618507862
#
# Total average train accuarcy: 0.82928
# Total average train loss: 0.007706478517055511
#
# [ Test epoch: 5 ]
#
# Total average test accuarcy: 0.8279
# Total average test loss: 0.00795914542376995
# Model Saved!
#
# Time elapsed: 1910.2282812595367
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.005706136580556631
#
# Current batch: 100
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.008206444792449474
#
# Current batch: 200
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.009107519872486591
#
# Current batch: 300
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.004246807657182217
#
# Current batch: 400
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.0076580895110964775
#
# Current batch: 500
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.0069716740399599075
#
# Current batch: 600
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004597084131091833
#
# Current batch: 700
# Current batch average train accuracy: 0.765625
# Current batch average train loss: 0.009693210013210773
#
# Total average train accuarcy: 0.84584
# Total average train loss: 0.006975101183056831
#
# [ Test epoch: 6 ]
#
# Total average test accuarcy: 0.7972
# Total average test loss: 0.009351934233307838
# Model Saved!
#
# Time elapsed: 2229.062295436859
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.006710189860314131
#
# Current batch: 100
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.005001113750040531
#
# Current batch: 200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.00509932916611433
#
# Current batch: 300
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.007239256054162979
#
# Current batch: 400
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004497782327234745
#
# Current batch: 500
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004099045880138874
#
# Current batch: 600
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.004603325854986906
#
# Current batch: 700
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.006543360650539398
#
# Total average train accuarcy: 0.8632
# Total average train loss: 0.00629590891033411
#
# [ Test epoch: 7 ]
#
# Total average test accuarcy: 0.8227
# Total average test loss: 0.008347089223563671
# Model Saved!
#
# Time elapsed: 2546.958603620529
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.00425791647285223
#
# Current batch: 100
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004858303815126419
#
# Current batch: 200
# Current batch average train accuracy: 0.796875
# Current batch average train loss: 0.008109332993626595
#
# Current batch: 300
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.00578194810077548
#
# Current batch: 400
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.00689904298633337
#
# Current batch: 500
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.0055628931149840355
#
# Current batch: 600
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.006552345585078001
#
# Current batch: 700
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0042004575952887535
#
# Total average train accuarcy: 0.87114
# Total average train loss: 0.005874283487796783
#
# [ Test epoch: 8 ]
#
# Total average test accuarcy: 0.7862
# Total average test loss: 0.009729747211933136
# Model Saved!
#
# Time elapsed: 2865.608457326889
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.004221824929118156
#
# Current batch: 100
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.006117066368460655
#
# Current batch: 200
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.00406268984079361
#
# Current batch: 300
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.002138830255717039
#
# Current batch: 400
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.00408509187400341
#
# Current batch: 500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.004746956750750542
#
# Current batch: 600
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.007112907711416483
#
# Current batch: 700
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0044119348749518394
#
# Total average train accuarcy: 0.8778
# Total average train loss: 0.0054794593816995625
#
# [ Test epoch: 9 ]
#
# Total average test accuarcy: 0.8136
# Total average test loss: 0.009107591427862645
# Model Saved!
#
# Time elapsed: 3182.6692521572113
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.0067312163300812244
#
# Current batch: 100
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.004934610798954964
#
# Current batch: 200
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.004703659564256668
#
# Current batch: 300
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.003670546691864729
#
# Current batch: 400
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.0041768234223127365
#
# Current batch: 500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.003610656363889575
#
# Current batch: 600
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.002559876535087824
#
# Current batch: 700
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.00586891220882535
#
# Total average train accuarcy: 0.88758
# Total average train loss: 0.005044650431871414
#
# [ Test epoch: 10 ]
#
# Total average test accuarcy: 0.7627
# Total average test loss: 0.011864493241906165
# Model Saved!
#
# Time elapsed: 3499.946525335312
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.005431707017123699
#
# Current batch: 100
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003876973409205675
#
# Current batch: 200
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.004565931390970945
#
# Current batch: 300
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004708636086434126
#
# Current batch: 400
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004364652093499899
#
# Current batch: 500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.003765144618228078
#
# Current batch: 600
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.004884023685008287
#
# Current batch: 700
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004368836060166359
#
# Total average train accuarcy: 0.8909
# Total average train loss: 0.004880977213531733
#
# [ Test epoch: 11 ]
#
# Total average test accuarcy: 0.8182
# Total average test loss: 0.008424390013515949
# Model Saved!
#
# Time elapsed: 3817.5516686439514
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.006505482364445925
#
# Current batch: 100
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0042634159326553345
#
# Current batch: 200
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.003490205854177475
#
# Current batch: 300
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.005397252272814512
#
# Current batch: 400
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.004368918016552925
#
# Current batch: 500
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.007045944686979055
#
# Current batch: 600
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.003492697374895215
#
# Current batch: 700
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.006569909863173962
#
# Total average train accuarcy: 0.89718
# Total average train loss: 0.0046325295330584045
#
# [ Test epoch: 12 ]
#
# Total average test accuarcy: 0.8425
# Total average test loss: 0.0071017182558774945
# Model Saved!
#
# Time elapsed: 4136.542110443115
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0024432260543107986
#
# Current batch: 100
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.002118296455591917
#
# Current batch: 200
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.00682325754314661
#
# Current batch: 300
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003999731969088316
#
# Current batch: 400
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.0035314348060637712
#
# Current batch: 500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.00305352546274662
#
# Current batch: 600
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.006534334272146225
#
# Current batch: 700
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.0043389261700212955
#
# Total average train accuarcy: 0.90268
# Total average train loss: 0.004386985762417316
#
# [ Test epoch: 13 ]
#
# Total average test accuarcy: 0.8241
# Total average test loss: 0.00844049577265978
# Model Saved!
#
# Time elapsed: 4453.98602938652
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.004259976092725992
#
# Current batch: 100
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.005738493986427784
#
# Current batch: 200
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.005293563473969698
#
# Current batch: 300
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003488863818347454
#
# Current batch: 400
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.00444331718608737
#
# Current batch: 500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.006353262346237898
#
# Current batch: 600
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.0059848749078810215
#
# Current batch: 700
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.005269253626465797
#
# Total average train accuarcy: 0.90264
# Total average train loss: 0.004333818396776915
#
# [ Test epoch: 14 ]
#
# Total average test accuarcy: 0.8408
# Total average test loss: 0.007509340991079807
# Model Saved!
#
# Time elapsed: 4771.886378765106
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.00258249556645751
#
# Current batch: 100
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.002474019769579172
#
# Current batch: 200
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.0045126574113965034
#
# Current batch: 300
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.003983347211033106
#
# Current batch: 400
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004864965099841356
#
# Current batch: 500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0024819381069391966
#
# Current batch: 600
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003755957819521427
#
# Current batch: 700
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.00403245072811842
#
# Total average train accuarcy: 0.91054
# Total average train loss: 0.00403114983022213
#
# [ Test epoch: 15 ]
#
# Total average test accuarcy: 0.816
# Total average test loss: 0.00880526491701603
# Model Saved!
#
# Time elapsed: 5090.56476855278
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003925012424588203
#
# Current batch: 100
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.002229729201644659
#
# Current batch: 200
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.0030506588518619537
#
# Current batch: 300
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.004557142499834299
#
# Current batch: 400
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004221482202410698
#
# Current batch: 500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.0035951780155301094
#
# Current batch: 600
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.004928413312882185
#
# Current batch: 700
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.004036633297801018
#
# Total average train accuarcy: 0.91248
# Total average train loss: 0.003994686163440347
#
# [ Test epoch: 16 ]
#
# Total average test accuarcy: 0.785
# Total average test loss: 0.011430796799063683
# Model Saved!
#
# Time elapsed: 5410.354989528656
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0029653836973011494
#
# Current batch: 100
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.005352879874408245
#
# Current batch: 200
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.003416028805077076
#
# Current batch: 300
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0025791891384869814
#
# Current batch: 400
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.0065926313400268555
#
# Current batch: 500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.003853184636682272
#
# Current batch: 600
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.005409847944974899
#
# Current batch: 700
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.007883407175540924
#
# Total average train accuarcy: 0.91366
# Total average train loss: 0.0038735186795890333
#
# [ Test epoch: 17 ]
#
# Total average test accuarcy: 0.8201
# Total average test loss: 0.008980636066198349
# Model Saved!
#
# Time elapsed: 5730.6905200481415
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.002181209158152342
#
# Current batch: 100
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0025274003855884075
#
# Current batch: 200
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0027970955707132816
#
# Current batch: 300
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0034215860068798065
#
# Current batch: 400
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0023118378594517708
#
# Current batch: 500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.004261935595422983
#
# Current batch: 600
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.002468346618115902
#
# Current batch: 700
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.003970055840909481
#
# Total average train accuarcy: 0.91928
# Total average train loss: 0.003665989958047867
#
# [ Test epoch: 18 ]
#
# Total average test accuarcy: 0.8424
# Total average test loss: 0.007627530986070633
# Model Saved!
#
# Time elapsed: 6050.34276008606
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0017582385335117579
#
# Current batch: 100
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.003816239070147276
#
# Current batch: 200
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.002176035428419709
#
# Current batch: 300
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.003231121227145195
#
# Current batch: 400
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.002518295543268323
#
# Current batch: 500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0019113204907625914
#
# Current batch: 600
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.004691084381192923
#
# Current batch: 700
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.004896219819784164
#
# Total average train accuarcy: 0.91848
# Total average train loss: 0.0036844984677433966
#
# [ Test epoch: 19 ]
#
# Total average test accuarcy: 0.812
# Total average test loss: 0.009689294382929802
# Model Saved!
#
# Time elapsed: 6368.545926570892
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0021756107453256845
#
# Current batch: 100
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.0027889402117580175
#
# Current batch: 200
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003418607171624899
#
# Current batch: 300
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.004224273841828108
#
# Current batch: 400
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.0035447997506707907
#
# Current batch: 500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.002268571173772216
#
# Current batch: 600
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.002261528978124261
#
# Current batch: 700
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.0037825433537364006
#
# Total average train accuarcy: 0.92006
# Total average train loss: 0.0035813225061446428
#
# [ Test epoch: 20 ]
#
# Total average test accuarcy: 0.8477
# Total average test loss: 0.007407666145265102
# Model Saved!
#
# Time elapsed: 6687.65318441391
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0012249082792550325
#
# Current batch: 100
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.002100937068462372
#
# Current batch: 200
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004629700910300016
#
# Current batch: 300
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.0052003501914441586
#
# Current batch: 400
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0035521890968084335
#
# Current batch: 500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0029451968148350716
#
# Current batch: 600
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.004927369300276041
#
# Current batch: 700
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.005110376980155706
#
# Total average train accuarcy: 0.9217
# Total average train loss: 0.0034975202336907387
#
# [ Test epoch: 21 ]
#
# Total average test accuarcy: 0.8472
# Total average test loss: 0.007301393564045429
# Model Saved!
#
# Time elapsed: 7006.0548367500305
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.984375
# Current batch average train loss: 0.0017659704899415374
#
# Current batch: 100
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003507707267999649
#
# Current batch: 200
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.00438956031575799
#
# Current batch: 300
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.002863817848265171
#
# Current batch: 400
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0036114153917878866
#
# Current batch: 500
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.003949552308768034
#
# Current batch: 600
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003685994539409876
#
# Current batch: 700
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003958937246352434
#
# Total average train accuarcy: 0.9227
# Total average train loss: 0.003476929318755865
#
# [ Test epoch: 22 ]
#
# Total average test accuarcy: 0.8082
# Total average test loss: 0.00940688225775957
# Model Saved!
#
# Time elapsed: 7325.336148023605
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.002764339791610837
#
# Current batch: 100
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0021189539693295956
#
# Current batch: 200
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0014137616381049156
#
# Current batch: 300
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.005533674266189337
#
# Current batch: 400
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.004063338506966829
#
# Current batch: 500
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.0026764818467199802
#
# Current batch: 600
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.00263301027007401
#
# Current batch: 700
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.004648210946470499
#
# Total average train accuarcy: 0.92494
# Total average train loss: 0.0033728654461726544
#
# [ Test epoch: 23 ]
#
# Total average test accuarcy: 0.8329
# Total average test loss: 0.00807637042850256
# Model Saved!
#
# Time elapsed: 7643.912978172302
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.004212627187371254
#
# Current batch: 100
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003063536249101162
#
# Current batch: 200
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0026129158213734627
#
# Current batch: 300
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.003252849681302905
#
# Current batch: 400
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.005204891320317984
#
# Current batch: 500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.005014036316424608
#
# Current batch: 600
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.004549968056380749
#
# Current batch: 700
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.004508472979068756
#
# Total average train accuarcy: 0.92826
# Total average train loss: 0.003262083510681987
#
# [ Test epoch: 24 ]
#
# Total average test accuarcy: 0.8447
# Total average test loss: 0.007447669278085232
# Model Saved!
#
# Time elapsed: 7963.380034685135
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.001982933608815074
#
# Current batch: 100
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0028789376374334097
#
# Current batch: 200
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003831738606095314
#
# Current batch: 300
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.005900900810956955
#
# Current batch: 400
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0017791802529245615
#
# Current batch: 500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.00521189346909523
#
# Current batch: 600
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.0049711233004927635
#
# Current batch: 700
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.0034326452296227217
#
# Total average train accuarcy: 0.92556
# Total average train loss: 0.0033816143303364516
#
# [ Test epoch: 25 ]
#
# Total average test accuarcy: 0.8648
# Total average test loss: 0.00656363223195076
# Model Saved!
#
# Time elapsed: 8281.909410953522
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.001545477076433599
#
# Current batch: 100
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.001718685613013804
#
# Current batch: 200
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0028215048369020224
#
# Current batch: 300
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.003966231364756823
#
# Current batch: 400
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003226452972739935
#
# Current batch: 500
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.0028690434992313385
#
# Current batch: 600
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.0034497531596571207
#
# Current batch: 700
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.00635899044573307
#
# Total average train accuarcy: 0.92782
# Total average train loss: 0.00322897681646049
#
# [ Test epoch: 26 ]
#
# Total average test accuarcy: 0.8588
# Total average test loss: 0.00721882187873125
# Model Saved!
#
# Time elapsed: 8601.145208597183
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.003248122287914157
#
# Current batch: 100
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.003220892511308193
#
# Current batch: 200
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.001810990390367806
#
# Current batch: 300
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.003016448114067316
#
# Current batch: 400
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0030992324464023113
#
# Current batch: 500
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.002164181787520647
#
# Current batch: 600
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.00225621834397316
#
# Current batch: 700
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.003600182244554162
#
# Total average train accuarcy: 0.92786
# Total average train loss: 0.003222356171309948
#
# [ Test epoch: 27 ]
#
# Total average test accuarcy: 0.8386
# Total average test loss: 0.008180869661271573
# Model Saved!
#
# Time elapsed: 8919.486230611801
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.004965819418430328
#
# Current batch: 100
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.0035386879462748766
#
# Current batch: 200
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0034338939003646374
#
# Current batch: 300
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.0035674565006047487
#
# Current batch: 400
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.0033304840326309204
#
# Current batch: 500
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0029768941458314657
#
# Current batch: 600
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.0018789159366860986
#
# Current batch: 700
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.006808594800531864
#
# Total average train accuarcy: 0.92652
# Total average train loss: 0.0032862093421816827
#
# [ Test epoch: 28 ]
#
# Total average test accuarcy: 0.8435
# Total average test loss: 0.007741579879820347
# Model Saved!
#
# Time elapsed: 9238.756905794144
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.0019338940037414432
#
# Current batch: 100
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0027860745321959257
#
# Current batch: 200
# Current batch average train accuracy: 0.984375
# Current batch average train loss: 0.0009436778491362929
#
# Current batch: 300
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.004339149687439203
#
# Current batch: 400
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.002778090536594391
#
# Current batch: 500
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0019630210008472204
#
# Current batch: 600
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0038401272613555193
#
# Current batch: 700
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.006861446890980005
#
# Total average train accuarcy: 0.93232
# Total average train loss: 0.0030498858922719954
#
# [ Test epoch: 29 ]
#
# Total average test accuarcy: 0.8537
# Total average test loss: 0.007075624665617943
# Model Saved!
#
# Time elapsed: 9557.085791826248
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0037337210960686207
#
# Current batch: 100
# Current batch average train accuracy: 0.984375
# Current batch average train loss: 0.0008460944518446922
#
# Current batch: 200
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0019038779428228736
#
# Current batch: 300
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0025656265206635
#
# Current batch: 400
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.001548591535538435
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0004810558457393199
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0005607543280348182
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00033832225017249584
#
# Total average train accuarcy: 0.9773
# Total average train loss: 0.0011566975251585245
#
# [ Test epoch: 30 ]
#
# Total average test accuarcy: 0.9113
# Total average test loss: 0.00420112284347415
# Model Saved!
#
# Time elapsed: 9876.005037784576
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.984375
# Current batch average train loss: 0.0007101970841176808
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0004994540940970182
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00025783164892345667
#
# Current batch: 300
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0016833501867949963
#
# Current batch: 400
# Current batch average train accuracy: 0.984375
# Current batch average train loss: 0.0003556700539775193
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0005346052930690348
#
# Current batch: 600
# Current batch average train accuracy: 0.984375
# Current batch average train loss: 0.0007840737816877663
#
# Current batch: 700
# Current batch average train accuracy: 0.984375
# Current batch average train loss: 0.00034714897628873587
#
# Total average train accuarcy: 0.9908
# Total average train loss: 0.0005960784619301558
#
# [ Test epoch: 31 ]
#
# Total average test accuarcy: 0.9127
# Total average test loss: 0.004137302916869521
# Model Saved!
#
# Time elapsed: 10193.974346876144
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.984375
# Current batch average train loss: 0.0011434743646532297
#
# Current batch: 100
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.0008226149366237223
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0002932446950580925
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0004876742896158248
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0004294870013836771
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00026398763293400407
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00032280886080116034
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0003519670863170177
#
# Total average train accuarcy: 0.99446
# Total average train loss: 0.0004061945277219638
#
# [ Test epoch: 32 ]
#
# Total average test accuarcy: 0.9147
# Total average test loss: 0.004169921677932144
# Model Saved!
#
# Time elapsed: 10512.91675043106
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001969223958440125
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00011081945558544248
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0002163152676075697
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00016142410458996892
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001882310607470572
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00013727351324632764
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001617854431970045
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.999182369327173e-05
#
# Total average train accuarcy: 0.99704
# Total average train loss: 0.00027485539447283375
#
# [ Test epoch: 33 ]
#
# Total average test accuarcy: 0.9157
# Total average test loss: 0.004161751570925116
# Model Saved!
#
# Time elapsed: 10831.543741226196
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001119185981224291
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00013697697431780398
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00012510412489064038
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00022077524045016617
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00012246883125044405
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00010246838792227209
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001320960436714813
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00026217158301733434
#
# Total average train accuarcy: 0.99824
# Total average train loss: 0.00020046968147158621
#
# [ Test epoch: 34 ]
#
# Total average test accuarcy: 0.9152
# Total average test loss: 0.004182284601032734
# Model Saved!
#
# Time elapsed: 11152.245921134949
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 8.675170101923868e-05
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00015315668133553118
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0002904362918343395
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001891343272291124
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.233306678244844e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001856596936704591
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00013256493548396975
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001438121689716354
#
# Total average train accuarcy: 0.99912
# Total average train loss: 0.00015974522598902695
#
# [ Test epoch: 35 ]
#
# Total average test accuarcy: 0.9169
# Total average test loss: 0.004225286976993084
# Model Saved!
#
# Time elapsed: 11471.844138145447
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.45047405466903e-05
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.599596574436873e-05
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00013293675146996975
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00012152818089816719
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.334723002510145e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.953645061003044e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.892824654234573e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00010377794387750328
#
# Total average train accuarcy: 0.9994
# Total average train loss: 0.00013107564217876644
#
# [ Test epoch: 36 ]
#
# Total average test accuarcy: 0.9156
# Total average test loss: 0.004297503653913736
# Model Saved!
#
# Time elapsed: 11792.400282144547
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00015328593144658953
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.698065484059043e-05
#
# Current batch: 200
# Current batch average train accuracy: 0.984375
# Current batch average train loss: 0.0005406520795077085
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.7943609135691077e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00013513414887711406
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.476607424905524e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.824575833277777e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00013352115638554096
#
# Total average train accuarcy: 0.99958
# Total average train loss: 0.00010953105642693117
#
# [ Test epoch: 37 ]
#
# Total average test accuarcy: 0.9156
# Total average test loss: 0.004289044493809342
# Model Saved!
#
# Time elapsed: 12112.018781661987
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00012030981451971456
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001572535838931799
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00011118113616248593
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.539805326610804e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.72435198794119e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.039965566946194e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.529637175844982e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.9844402383314446e-05
#
# Total average train accuarcy: 0.99972
# Total average train loss: 9.44774451921694e-05
#
# [ Test epoch: 38 ]
#
# Total average test accuarcy: 0.9161
# Total average test loss: 0.004260447490215301
# Model Saved!
#
# Time elapsed: 12432.539345502853
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001597832451807335
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.731539906468242e-05
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.226299203466624e-05
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 8.949593757279217e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 8.949177572503686e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 2.091618807753548e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0002073942741844803
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.28923376603052e-05
#
# Total average train accuarcy: 0.99978
# Total average train loss: 8.817742945160716e-05
#
# [ Test epoch: 39 ]
#
# Total average test accuarcy: 0.9163
# Total average test loss: 0.004306322087347507
# Model Saved!
#
# Time elapsed: 12752.133409500122
#
# [ Train epoch: 40 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.7630037190392613e-05
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 2.0481924366322346e-05
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 1.718303610687144e-05
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.659785165335052e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.601125980727375e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.457314596744254e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.230633178143762e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00012391364725772291
#
# Total average train accuarcy: 0.9999
# Total average train loss: 7.369915870716796e-05
#
# [ Test epoch: 40 ]
#
# Total average test accuarcy: 0.9167
# Total average test loss: 0.004327768823876977
# Model Saved!
#
# Time elapsed: 13072.832600593567
#
# [ Train epoch: 41 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.7261404688470066e-05
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.118952710996382e-05
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 2.7287451302981935e-05
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.442247442668304e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00015417342365253717
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00010316204861737788
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 9.788495663087815e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.513639916898683e-05
#
# Total average train accuarcy: 0.99992
# Total average train loss: 7.025898682884872e-05
#
# [ Test epoch: 41 ]
#
# Total average test accuarcy: 0.9173
# Total average test loss: 0.004265538985282182
# Model Saved!
#
# Time elapsed: 13392.551530599594
#
# [ Train epoch: 42 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00011569344496820122
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00015809306933078915
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00018822647689376026
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 1.1444621122791432e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.690890197409317e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.6786113671259955e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.058853326365352e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.317779505276121e-05
#
# Total average train accuarcy: 0.99994
# Total average train loss: 6.992401254130528e-05
#
# [ Test epoch: 42 ]
#
# Total average test accuarcy: 0.9166
# Total average test loss: 0.004287893443182111
# Model Saved!
#
# Time elapsed: 13713.410969495773
#
# [ Train epoch: 43 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.107327837729827e-05
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.676277628983371e-05
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.682277747429907e-05
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 2.998599666170776e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.788354610558599e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.808255420764908e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.55125121132005e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 2.4676943212398328e-05
#
# Total average train accuarcy: 0.99996
# Total average train loss: 6.740213166223839e-05
#
# [ Test epoch: 43 ]
#
# Total average test accuarcy: 0.9167
# Total average test loss: 0.004281112037599087
# Model Saved!
#
# Time elapsed: 14033.226637601852
#
# [ Train epoch: 44 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.46337326138746e-05
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.845054329256527e-05
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 9.432643128093332e-05
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.086272747372277e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.9336787924403325e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.581798541243188e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.259437653468922e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 9.1903108113911e-05
#
# Total average train accuarcy: 0.99992
# Total average train loss: 6.74570339510683e-05
#
# [ Test epoch: 44 ]
#
# Total average test accuarcy: 0.9162
# Total average test loss: 0.004276020734012127
# Model Saved!
#
# Time elapsed: 14354.383839845657
#
# [ Train epoch: 45 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0001410654658684507
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.069424514658749e-05
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 8.463704580208287e-05
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.119560253457166e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.165231803199276e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.509731661528349e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.984518742887303e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.6850822400301695e-05
#
# Total average train accuarcy: 0.99998
# Total average train loss: 6.455582492868415e-05
#
# [ Test epoch: 45 ]
#
# Total average test accuarcy: 0.9168
# Total average test loss: 0.004228028240427375
# Model Saved!
#
# Time elapsed: 14674.619542837143
#
# [ Train epoch: 46 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 2.0544046492432244e-05
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.224195461370982e-05
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 8.943153807194903e-05
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.249605550896376e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.923249070998281e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.253246904932894e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.668287899927236e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00012868919293396175
#
# Total average train accuarcy: 0.99994
# Total average train loss: 6.486375138396398e-05
#
# [ Test epoch: 46 ]
#
# Total average test accuarcy: 0.9171
# Total average test loss: 0.004270232402905822
# Model Saved!
#
# Time elapsed: 14995.876942634583
#
# [ Train epoch: 47 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0002119157579727471
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.019218901405111e-05
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.033584627904929e-05
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.512173498165794e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.798723188694566e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.8562316806055605e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.4390238801715896e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.576677697012201e-05
#
# Total average train accuarcy: 0.99996
# Total average train loss: 6.456853605457582e-05
#
# [ Test epoch: 47 ]
#
# Total average test accuarcy: 0.9159
# Total average test loss: 0.004286787558346987
# Model Saved!
#
# Time elapsed: 15315.668852806091
#
# [ Train epoch: 48 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.3016661948058754e-05
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0002239549794467166
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.460996206034906e-05
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.01911048963666e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 6.553733692271635e-05
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.49572001141496e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 2.2590473236050457e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.4453943953849375e-05
#
# Total average train accuarcy: 0.99998
# Total average train loss: 6.540050062234514e-05
#
# [ Test epoch: 48 ]
#
# Total average test accuarcy: 0.9161
# Total average test loss: 0.004306518624350429
# Model Saved!
#
# Time elapsed: 15636.782542228699
#
# [ Train epoch: 49 ]
#
# Current batch: 0
# Current batch average train accuracy: 1.0
# Current batch average train loss: 3.564657527022064e-05
#
# Current batch: 100
# Current batch average train accuracy: 1.0
# Current batch average train loss: 5.756442260462791e-05
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.253437070176005e-05
#
# Current batch: 300
# Current batch average train accuracy: 1.0
# Current batch average train loss: 7.284676394192502e-05
#
# Current batch: 400
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.00013292110816109926
#
# Current batch: 500
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.185006037005223e-05
#
# Current batch: 600
# Current batch average train accuracy: 1.0
# Current batch average train loss: 4.7561647079419345e-05
#
# Current batch: 700
# Current batch average train accuracy: 1.0
# Current batch average train loss: 1.601612166268751e-05
#
# Total average train accuarcy: 0.99996
# Total average train loss: 6.582059842185118e-05
#
# [ Test epoch: 49 ]
#
# Total average test accuarcy: 0.9161
# Total average test loss: 0.0042899400904774666
# Model Saved!
#
# Time elapsed: 15957.041588306427
