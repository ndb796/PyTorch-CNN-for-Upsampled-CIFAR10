# %% [markdown]
# #### <b>ResNet18 모델 아키텍처 정의</b>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out) # 출력: [batch_size, 512, 4, 4]
        out = F.avg_pool2d(out, 16) # 출력: [batch_size, 512, 1, 1]
        out = out.view(out.size(0), -1) # 출력: [batch_size, 512]
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# #### <b>데이터셋(Dataset) 다운로드 및 불러오기</b>

# %%
import torchvision
import torchvision.transforms as transforms

transform_train = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# #### <b>환경 설정 및 학습(Training) 함수 정의</b>

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)

learning_rate = 0.1
file_name = 'resnet18_cifar10.pth'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        current_correct = predicted.eq(targets).sum().item()
        correct += current_correct
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current batch average train accuracy:', current_correct / targets.size(0))
            print('Current batch average train loss:', loss.item() / targets.size(0))

    print('\nTotal average train accuarcy:', correct / total)
    print('Total average train loss:', train_loss / total)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTotal average test accuarcy:', correct / total)
    print('Total average test loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

# %% [markdown]
# #### <b>학습(Training) 진행</b>

# %%
import time


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 30:
        lr /= 10
    if epoch >= 40:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

start_time = time.time()

for epoch in range(0, 50):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
    print('\nTime elapsed:', time.time() - start_time)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.0625
# Current batch average train loss: 0.07686751335859299
#
# Current batch: 100
# Current batch average train accuracy: 0.15625
# Current batch average train loss: 0.06607278436422348
#
# Current batch: 200
# Current batch average train accuracy: 0.125
# Current batch average train loss: 0.06424238532781601
#
# Current batch: 300
# Current batch average train accuracy: 0.0625
# Current batch average train loss: 0.06716970354318619
#
# Current batch: 400
# Current batch average train accuracy: 0.3125
# Current batch average train loss: 0.05748102441430092
#
# Current batch: 500
# Current batch average train accuracy: 0.1875
# Current batch average train loss: 0.06522181630134583
#
# Current batch: 600
# Current batch average train accuracy: 0.375
# Current batch average train loss: 0.05630964785814285
#
# Current batch: 700
# Current batch average train accuracy: 0.21875
# Current batch average train loss: 0.059522684663534164
#
# Current batch: 800
# Current batch average train accuracy: 0.15625
# Current batch average train loss: 0.06579132378101349
#
# Current batch: 900
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.0522768534719944
#
# Current batch: 1000
# Current batch average train accuracy: 0.375
# Current batch average train loss: 0.053435586392879486
#
# Current batch: 1100
# Current batch average train accuracy: 0.375
# Current batch average train loss: 0.05315236374735832
#
# Current batch: 1200
# Current batch average train accuracy: 0.1875
# Current batch average train loss: 0.05745958536863327
#
# Current batch: 1300
# Current batch average train accuracy: 0.28125
# Current batch average train loss: 0.04775334149599075
#
# Current batch: 1400
# Current batch average train accuracy: 0.375
# Current batch average train loss: 0.04652687534689903
#
# Current batch: 1500
# Current batch average train accuracy: 0.25
# Current batch average train loss: 0.05453674867749214
#
# Total average train accuarcy: 0.2862
# Total average train loss: 0.05974668169975281
#
# [ Test epoch: 0 ]
#
# Total average test accuarcy: 0.4308
# Total average test loss: 0.04823074964284897
# Model Saved!
#
# Time elapsed: 1463.877299785614
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.34375
# Current batch average train loss: 0.05363387614488602
#
# Current batch: 100
# Current batch average train accuracy: 0.40625
# Current batch average train loss: 0.056932784616947174
#
# Current batch: 200
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.04234980046749115
#
# Current batch: 300
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.04151517152786255
#
# Current batch: 400
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.04163823649287224
#
# Current batch: 500
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.04236334189772606
#
# Current batch: 600
# Current batch average train accuracy: 0.40625
# Current batch average train loss: 0.0434638150036335
#
# Current batch: 700
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03696713596582413
#
# Current batch: 800
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.04057280346751213
#
# Current batch: 900
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03969443216919899
#
# Current batch: 1000
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03893290460109711
#
# Current batch: 1100
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.032849326729774475
#
# Current batch: 1200
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.02813267707824707
#
# Current batch: 1300
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.029574088752269745
#
# Current batch: 1400
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.03335278481245041
#
# Current batch: 1500
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.03037341684103012
#
# Total average train accuarcy: 0.5132
# Total average train loss: 0.04145556057691574
#
# [ Test epoch: 1 ]
#
# Total average test accuarcy: 0.6052
# Total average test loss: 0.035397903364896774
# Model Saved!
#
# Time elapsed: 2925.1595413684845
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.029252074658870697
#
# Current batch: 100
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.024360835552215576
#
# Current batch: 200
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.044826749712228775
#
# Current batch: 300
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03973916918039322
#
# Current batch: 400
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.023698050528764725
#
# Current batch: 500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.03346296399831772
#
# Current batch: 600
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.039955757558345795
#
# Current batch: 700
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.034163545817136765
#
# Current batch: 800
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.020568162202835083
#
# Current batch: 900
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.02786274440586567
#
# Current batch: 1000
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01890929602086544
#
# Current batch: 1100
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.027395758777856827
#
# Current batch: 1200
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03746425360441208
#
# Current batch: 1300
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.036285556852817535
#
# Current batch: 1400
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.03873710334300995
#
# Current batch: 1500
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.02760946750640869
#
# Total average train accuarcy: 0.65174
# Total average train loss: 0.03072597139954567
#
# [ Test epoch: 2 ]
#
# Total average test accuarcy: 0.6213
# Total average test loss: 0.033332322919368745
# Model Saved!
#
# Time elapsed: 4388.376596927643
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.03145008906722069
#
# Current batch: 100
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.028338808566331863
#
# Current batch: 200
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.023384083062410355
#
# Current batch: 300
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.023230155929923058
#
# Current batch: 400
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.02972050942480564
#
# Current batch: 500
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.01972113735973835
#
# Current batch: 600
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.024458935484290123
#
# Current batch: 700
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.019150635227560997
#
# Current batch: 800
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.022176221013069153
#
# Current batch: 900
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.017685536295175552
#
# Current batch: 1000
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.03268735855817795
#
# Current batch: 1100
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.020899701863527298
#
# Current batch: 1200
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01544229406863451
#
# Current batch: 1300
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.018397821113467216
#
# Current batch: 1400
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.01640496589243412
#
# Current batch: 1500
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.024326462298631668
#
# Total average train accuarcy: 0.71788
# Total average train loss: 0.025191414002776146
#
# [ Test epoch: 3 ]
#
# Total average test accuarcy: 0.7037
# Total average test loss: 0.026279432073235513
# Model Saved!
#
# Time elapsed: 5846.0594663619995
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.018852081149816513
#
# Current batch: 100
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.022075125947594643
#
# Current batch: 200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.013913841918110847
#
# Current batch: 300
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.020860793069005013
#
# Current batch: 400
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.022256167605519295
#
# Current batch: 500
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.022692536935210228
#
# Current batch: 600
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.04673989862203598
#
# Current batch: 700
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.02354135550558567
#
# Current batch: 800
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.02293926477432251
#
# Current batch: 900
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.021416308358311653
#
# Current batch: 1000
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.024083580821752548
#
# Current batch: 1100
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.03751989081501961
#
# Current batch: 1200
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.030656374990940094
#
# Current batch: 1300
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.021489258855581284
#
# Current batch: 1400
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.03377790004014969
#
# Current batch: 1500
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.023278046399354935
#
# Total average train accuarcy: 0.7534
# Total average train loss: 0.022028893364667894
#
# [ Test epoch: 4 ]
#
# Total average test accuarcy: 0.6875
# Total average test loss: 0.027873015588521958
# Model Saved!
#
# Time elapsed: 7309.900760889053
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.011420540511608124
#
# Current batch: 100
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.02128991298377514
#
# Current batch: 200
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.02320810966193676
#
# Current batch: 300
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.03004714660346508
#
# Current batch: 400
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.018563799560070038
#
# Current batch: 500
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.027292734012007713
#
# Current batch: 600
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.01695045828819275
#
# Current batch: 700
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.023403681814670563
#
# Current batch: 800
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.017106814309954643
#
# Current batch: 900
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03158460557460785
#
# Current batch: 1000
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.028678277507424355
#
# Current batch: 1100
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.028328699991106987
#
# Current batch: 1200
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.021886903792619705
#
# Current batch: 1300
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.019551225006580353
#
# Current batch: 1400
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.0198985505849123
#
# Current batch: 1500
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.024451442062854767
#
# Total average train accuarcy: 0.78102
# Total average train loss: 0.0199485020250082
#
# [ Test epoch: 5 ]
#
# Total average test accuarcy: 0.7595
# Total average test loss: 0.021458060491085052
# Model Saved!
#
# Time elapsed: 8769.465682506561
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01407565362751484
#
# Current batch: 100
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.012132159434258938
#
# Current batch: 200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.010065057314932346
#
# Current batch: 300
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.03998763859272003
#
# Current batch: 400
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.014712202362716198
#
# Current batch: 500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.014704730361700058
#
# Current batch: 600
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.023705482482910156
#
# Current batch: 700
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.016587229445576668
#
# Current batch: 800
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.02791217900812626
#
# Current batch: 900
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.017576145008206367
#
# Current batch: 1000
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01811450906097889
#
# Current batch: 1100
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.011085313744843006
#
# Current batch: 1200
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.031017020344734192
#
# Current batch: 1300
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.017460227012634277
#
# Current batch: 1400
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.011800004169344902
#
# Current batch: 1500
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.019494105130434036
#
# Total average train accuarcy: 0.79644
# Total average train loss: 0.018539721848964692
#
# [ Test epoch: 6 ]
#
# Total average test accuarcy: 0.7352
# Total average test loss: 0.024732248613238333
# Model Saved!
#
# Time elapsed: 10231.68286705017
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.02123432792723179
#
# Current batch: 100
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.02306516095995903
#
# Current batch: 200
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01614784076809883
#
# Current batch: 300
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01763194240629673
#
# Current batch: 400
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.015116002410650253
#
# Current batch: 500
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.021252721548080444
#
# Current batch: 600
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.026141751557588577
#
# Current batch: 700
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.010097678750753403
#
# Current batch: 800
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.009433628991246223
#
# Current batch: 900
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.016436785459518433
#
# Current batch: 1000
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.010863364674150944
#
# Current batch: 1100
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.021136723458766937
#
# Current batch: 1200
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.02589515969157219
#
# Current batch: 1300
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.012342135421931744
#
# Current batch: 1400
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.02392807975411415
#
# Current batch: 1500
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.011137399822473526
#
# Total average train accuarcy: 0.8078
# Total average train loss: 0.017598343154788018
#
# [ Test epoch: 7 ]
#
# Total average test accuarcy: 0.7358
# Total average test loss: 0.024443288603425026
# Model Saved!
#
# Time elapsed: 11689.813034772873
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.021548260003328323
#
# Current batch: 100
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.022210001945495605
#
# Current batch: 200
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.021881110966205597
#
# Current batch: 300
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.012249517254531384
#
# Current batch: 400
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.019891705363988876
#
# Current batch: 500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.007841590791940689
#
# Current batch: 600
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.021758360788226128
#
# Current batch: 700
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.018637334927916527
#
# Current batch: 800
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.012963175773620605
#
# Current batch: 900
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.020035622641444206
#
# Current batch: 1000
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.024961259216070175
#
# Current batch: 1100
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.023486090824007988
#
# Current batch: 1200
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.02660614252090454
#
# Current batch: 1300
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.032188475131988525
#
# Current batch: 1400
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.01216678787022829
#
# Current batch: 1500
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.02600264921784401
#
# Total average train accuarcy: 0.81452
# Total average train loss: 0.01678210345700383
#
# [ Test epoch: 8 ]
#
# Total average test accuarcy: 0.7967
# Total average test loss: 0.018363763220608235
# Model Saved!
#
# Time elapsed: 13152.412504434586
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.013233587145805359
#
# Current batch: 100
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.008258678019046783
#
# Current batch: 200
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.010950888507068157
#
# Current batch: 300
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.017232807353138924
#
# Current batch: 400
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.010398287326097488
#
# Current batch: 500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01363933365792036
#
# Current batch: 600
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.015078345313668251
#
# Current batch: 700
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.01585795171558857
#
# Current batch: 800
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.018010500818490982
#
# Current batch: 900
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.020299382507801056
#
# Current batch: 1000
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.017264848574995995
#
# Current batch: 1100
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.021858254447579384
#
# Current batch: 1200
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.013098619878292084
#
# Current batch: 1300
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.013902289792895317
#
# Current batch: 1400
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.008639400824904442
#
# Current batch: 1500
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.021298490464687347
#
# Total average train accuarcy: 0.82666
# Total average train loss: 0.015790809151083232
#
# [ Test epoch: 9 ]
#
# Total average test accuarcy: 0.7762
# Total average test loss: 0.021034148609638214
# Model Saved!
#
# Time elapsed: 14608.563358068466
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.015232774429023266
#
# Current batch: 100
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.014741599559783936
#
# Current batch: 200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.01575261726975441
#
# Current batch: 300
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.014780464582145214
#
# Current batch: 400
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.016534896567463875
#
# Current batch: 500
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.028995539993047714
#
# Current batch: 600
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.02050595171749592
#
# Current batch: 700
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.020630700513720512
#
# Current batch: 800
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.017984511330723763
#
# Current batch: 900
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.007839121855795383
#
# Current batch: 1000
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.016807029023766518
#
# Current batch: 1100
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.019705601036548615
#
# Current batch: 1200
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.02610517106950283
#
# Current batch: 1300
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.0159747451543808
#
# Current batch: 1400
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.023314515128731728
#
# Current batch: 1500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01464864518493414
#
# Total average train accuarcy: 0.83032
# Total average train loss: 0.015405277881920337
#
# [ Test epoch: 10 ]
#
# Total average test accuarcy: 0.7786
# Total average test loss: 0.019749661226570608
# Model Saved!
#
# Time elapsed: 16065.690858125687
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.01182050071656704
#
# Current batch: 100
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.004723687656223774
#
# Current batch: 200
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.02245141565799713
#
# Current batch: 300
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.020577769726514816
#
# Current batch: 400
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.006907170172780752
#
# Current batch: 500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.008646178990602493
#
# Current batch: 600
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.008165811188519001
#
# Current batch: 700
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.013862714171409607
#
# Current batch: 800
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.015502320602536201
#
# Current batch: 900
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.014477729797363281
#
# Current batch: 1000
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.012007037177681923
#
# Current batch: 1100
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.02936055324971676
#
# Current batch: 1200
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.009872525930404663
#
# Current batch: 1300
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.011210374534130096
#
# Current batch: 1400
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.019510434940457344
#
# Current batch: 1500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.02314778044819832
#
# Total average train accuarcy: 0.83772
# Total average train loss: 0.014859992434680462
#
# [ Test epoch: 11 ]
#
# Total average test accuarcy: 0.8107
# Total average test loss: 0.017618680165708066
# Model Saved!
#
# Time elapsed: 17518.890508651733
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.015302934683859348
#
# Current batch: 100
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.019662775099277496
#
# Current batch: 200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.015348629094660282
#
# Current batch: 300
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.01691686362028122
#
# Current batch: 400
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.03295283392071724
#
# Current batch: 500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.02060575969517231
#
# Current batch: 600
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.022639017552137375
#
# Current batch: 700
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.017576908692717552
#
# Current batch: 800
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.020919520407915115
#
# Current batch: 900
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.007592698559165001
#
# Current batch: 1000
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.01722988486289978
#
# Current batch: 1100
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.010040849447250366
#
# Current batch: 1200
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.01099249254912138
#
# Current batch: 1300
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01404794305562973
#
# Current batch: 1400
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.015283931978046894
#
# Current batch: 1500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.009129000827670097
#
# Total average train accuarcy: 0.8405
# Total average train loss: 0.014525373723804951
#
# [ Test epoch: 12 ]
#
# Total average test accuarcy: 0.7304
# Total average test loss: 0.028468169268965723
# Model Saved!
#
# Time elapsed: 18976.87643814087
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.008158489130437374
#
# Current batch: 100
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.017654847353696823
#
# Current batch: 200
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.0030787959694862366
#
# Current batch: 300
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01530260406434536
#
# Current batch: 400
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.012303338386118412
#
# Current batch: 500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01732831820845604
#
# Current batch: 600
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.017767973244190216
#
# Current batch: 700
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.02065560407936573
#
# Current batch: 800
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.005657617002725601
#
# Current batch: 900
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.02126774750649929
#
# Current batch: 1000
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.012422425672411919
#
# Current batch: 1100
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.01192056480795145
#
# Current batch: 1200
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.021577535197138786
#
# Current batch: 1300
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.01814248599112034
#
# Current batch: 1400
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.013160712085664272
#
# Current batch: 1500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.013598994351923466
#
# Total average train accuarcy: 0.8427
# Total average train loss: 0.014279148020148277
#
# [ Test epoch: 13 ]
#
# Total average test accuarcy: 0.816
# Total average test loss: 0.01688166352584958
# Model Saved!
#
# Time elapsed: 20431.137542247772
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.02138076350092888
#
# Current batch: 100
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.006743164733052254
#
# Current batch: 200
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.016443196684122086
#
# Current batch: 300
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01414002850651741
#
# Current batch: 400
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.011311951093375683
#
# Current batch: 500
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.017132610082626343
#
# Current batch: 600
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.013376190327107906
#
# Current batch: 700
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.018819864839315414
#
# Current batch: 800
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.015866247937083244
#
# Current batch: 900
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.017861971631646156
#
# Current batch: 1000
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.012365881353616714
#
# Current batch: 1100
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.018686195835471153
#
# Current batch: 1200
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.01252817828208208
#
# Current batch: 1300
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.012644183821976185
#
# Current batch: 1400
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.020945696160197258
#
# Current batch: 1500
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.01702338270843029
#
# Total average train accuarcy: 0.84508
# Total average train loss: 0.01401952325463295
#
# [ Test epoch: 14 ]
#
# Total average test accuarcy: 0.7354
# Total average test loss: 0.02633262553215027
# Model Saved!
#
# Time elapsed: 21887.57792878151
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.020760605111718178
#
# Current batch: 100
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.009021895937621593
#
# Current batch: 200
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.015613134950399399
#
# Current batch: 300
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.013107320293784142
#
# Current batch: 400
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.008382194675505161
#
# Current batch: 500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.01344153843820095
#
# Current batch: 600
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.015124364756047726
#
# Current batch: 700
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.024771299213171005
#
# Current batch: 800
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.016294604167342186
#
# Current batch: 900
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.021044624969363213
#
# Current batch: 1000
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.010019201785326004
#
# Current batch: 1100
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.012799429707229137
#
# Current batch: 1200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.014399261213839054
#
# Current batch: 1300
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.013293913565576077
#
# Current batch: 1400
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.020793279632925987
#
# Current batch: 1500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.012243022210896015
#
# Total average train accuarcy: 0.85074
# Total average train loss: 0.013666706591397524
#
# [ Test epoch: 15 ]
#
# Total average test accuarcy: 0.6926
# Total average test loss: 0.03273640625476837
# Model Saved!
#
# Time elapsed: 23339.316603660583
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.014306549914181232
#
# Current batch: 100
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.012273192405700684
#
# Current batch: 200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.00911826640367508
#
# Current batch: 300
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.023239299654960632
#
# Current batch: 400
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.009984428994357586
#
# Current batch: 500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.014312886632978916
#
# Current batch: 600
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.01319449208676815
#
# Current batch: 700
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.01475365087389946
#
# Current batch: 800
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.010522684082388878
#
# Current batch: 900
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.010544078424572945
#
# Current batch: 1000
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.006216764450073242
#
# Current batch: 1100
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.021275214850902557
#
# Current batch: 1200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.009557383134961128
#
# Current batch: 1300
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.00846169050782919
#
# Current batch: 1400
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.012358360923826694
#
# Current batch: 1500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.011296296492218971
#
# Total average train accuarcy: 0.8513
# Total average train loss: 0.013452561225295067
#
# [ Test epoch: 16 ]
#
# Total average test accuarcy: 0.7955
# Total average test loss: 0.01862013898640871
# Model Saved!
#
# Time elapsed: 24791.244616270065
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.010197116062045097
#
# Current batch: 100
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.018431738018989563
#
# Current batch: 200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.01701372303068638
#
# Current batch: 300
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.0105160903185606
#
# Current batch: 400
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.01610490307211876
#
# Current batch: 500
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.01277791615575552
#
# Current batch: 600
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.010485652834177017
#
# Current batch: 700
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.02286614663898945
#
# Current batch: 800
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.01364838145673275
#
# Current batch: 900
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.02343040145933628
#
# Current batch: 1000
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.019325105473399162
#
# Current batch: 1100
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.027167120948433876
#
# Current batch: 1200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.011911759153008461
#
# Current batch: 1300
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.014980892650783062
#
# Current batch: 1400
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.02459043823182583
#
# Current batch: 1500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.006974646355956793
#
# Total average train accuarcy: 0.85408
# Total average train loss: 0.013351406434327364
#
# [ Test epoch: 17 ]
#
# Total average test accuarcy: 0.8154
# Total average test loss: 0.016865068931877614
# Model Saved!
#
# Time elapsed: 26228.720506191254
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.01210106909275055
#
# Current batch: 100
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.020620446652173996
#
# Current batch: 200
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.016738414764404297
#
# Current batch: 300
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.011921463534235954
#
# Current batch: 400
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.019638948142528534
#
# Current batch: 500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.013302105478942394
#
# Current batch: 600
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.007946266792714596
#
# Current batch: 700
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.006053496152162552
#
# Current batch: 800
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.017143836244940758
#
# Current batch: 900
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.007780252490192652
#
# Current batch: 1000
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.017170658335089684
#
# Current batch: 1100
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.020611239597201347
#
# Current batch: 1200
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.01692902483046055
#
# Current batch: 1300
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.016628911718726158
#
# Current batch: 1400
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.01457944605499506
#
# Current batch: 1500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.006569636985659599
#
# Total average train accuarcy: 0.85376
# Total average train loss: 0.013291924838423728
#
# [ Test epoch: 18 ]
#
# Total average test accuarcy: 0.8278
# Total average test loss: 0.015437381909787655
# Model Saved!
#
# Time elapsed: 27665.959203720093
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.005505810957401991
#
# Current batch: 100
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.009666538797318935
#
# Current batch: 200
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01262801606208086
#
# Current batch: 300
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.016837144270539284
#
# Current batch: 400
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.015940479934215546
#
# Current batch: 500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.011175752617418766
#
# Current batch: 600
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.011307140812277794
#
# Current batch: 700
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.015743287280201912
#
# Current batch: 800
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.010998801328241825
#
# Current batch: 900
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.006735417526215315
#
# Current batch: 1000
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.02230897918343544
#
# Current batch: 1100
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01432083174586296
#
# Current batch: 1200
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01804661750793457
#
# Current batch: 1300
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.01709079183638096
#
# Current batch: 1400
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.02829751931130886
#
# Current batch: 1500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.016504572704434395
#
# Total average train accuarcy: 0.85542
# Total average train loss: 0.013105322921425104
#
# [ Test epoch: 19 ]
#
# Total average test accuarcy: 0.8048
# Total average test loss: 0.0185270784817636
# Model Saved!
#
# Time elapsed: 29099.61820793152
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.015457193367183208
#
# Current batch: 100
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.006793495733290911
#
# Current batch: 200
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.021920861676335335
#
# Current batch: 300
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.016953380778431892
#
# Current batch: 400
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.0120606804266572
#
# Current batch: 500
# Current batch average train accuracy: 0.96875
# Current batch average train loss: 0.00420965813100338
#
# Current batch: 600
# Current batch average train accuracy: 0.75
# Current batch average train loss: 0.01949148252606392
#
# Current batch: 700
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.008054298348724842
#
# Current batch: 800
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.015946876257658005
#
# Current batch: 900
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.00847634021192789
#
# Current batch: 1000
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.016781222075223923
#
# Current batch: 1100
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.008793618530035019
#
# Current batch: 1200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.011389050632715225
#
# Current batch: 1300
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.009201820939779282
#
# Current batch: 1400
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.015443334355950356
#
# Current batch: 1500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.013227987103164196
#
# Total average train accuarcy: 0.85918
# Total average train loss: 0.012841846858859063
#
# [ Test epoch: 20 ]
#
# Total average test accuarcy: 0.8183
# Total average test loss: 0.01634876489341259
# Model Saved!
#
# Time elapsed: 30537.398366451263
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.00954450573772192
#
# Current batch: 100
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.017993858084082603
#
# Current batch: 200
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.006774787791073322
#
# Current batch: 300
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.008691149763762951
#
# Current batch: 400
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.012086602859199047
#
# Current batch: 500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.011021032929420471
#
# Current batch: 600
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.009978021495044231
#
# Current batch: 700
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.013250582851469517
#
# Current batch: 800
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.013632424175739288
#
# Current batch: 900
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.0088542765006423
#
# Current batch: 1000
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.012768509797751904
#
# Current batch: 1100
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.015312088653445244
#
# Current batch: 1200
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.019166365265846252
#
# Current batch: 1300
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.007103773765265942
#
# Current batch: 1400
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.006583360023796558
#
# Current batch: 1500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.012742561288177967
#
# Total average train accuarcy: 0.85868
# Total average train loss: 0.012841289022490382
#
# [ Test epoch: 21 ]
#
# Total average test accuarcy: 0.8072
# Total average test loss: 0.017620653624087573
# Model Saved!
#
# Time elapsed: 31972.019554376602
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.008241893723607063
#
# Current batch: 100
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.011806017719209194
#
# Current batch: 200
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.009768867865204811
